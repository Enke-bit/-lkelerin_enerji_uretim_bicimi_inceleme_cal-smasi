# %% [markdown]
# # İş problemi ülkelerin yenilebilir enerji üretim oranları etkileyen faktörler nelerdir. Bunu problem olarak tanımlayıp bakalım.

# %%
- Veriye ilk bakış;
1. Verinin ilk beş verisine bakış.
2. Verinin son beş verisine bakış.
3. Veri seti hakkında ve indexler hakkında bilgi.
4. Yapısal olrak veri ististiksel inceleme.
5. Veri setindeki ixdexler hakkında bilgi.
6. Veri setindeki boş veri varmı bakmak.
7. Veri setindeki yapısal şekline bakalım.

- Veri Görselleştirmesi;
1. Ülkelerin enerji üretim acısından inceleme.
2. enerji üretim türleri ve buna bağlı üretim miktarı.
3. Ülkelerin enerji üretim miktarı ve üretim şekli acsından inceleme.
4. Ülkelerin enerji üretim miktarı ve kamu özel ortaklığı üretim acsından inceleme.
5. Ülkelerin enerji üretim miktarı ve bçlgesel anlaşmalı üretim acsından inceleme.
6. Kurulu küç kapasitesine bakalım.
7. Üretim kapesitesinin ülkeler acısından.
8. Fransa özelinde Rusya - Ukaranya savaşı sonrası Fransanın üretim kapesitesini artırmada nasıl bir politika yapmış ona balaım.
9. Üretim kapesityesi ve yıl odaklı bakalım şimdide.
10. Burda yıllara ve üretim miktarı ve bunun hangi tür üretim ile olduğuna bakılm.
11. Üretim kapesitesi bakımından yıllara ve üretim türlerine göre bakılm.
12. Enerji tüketimine bakalım yıllara göre.
13. Enerji tüketimine bakalım yıllara göre ve enerji üretim türleri acısından bakaılm.
14. Yıllara göre göre yenilebilir enerji oranı.
15. Yıllara göre göre yenilebilir enerji oranını ülkelere odaklı inceleme.
16. Bu grafikte yenilebilir enerji kaynakları acısından ülkeleri 2023 yılı için inceleyelim.
17. Yenilebilir enerji kaynaklarının oranı ve bunların yapılma proje anlaşmaları.
18. kişi başına düşen milli gelir ve enerji üretimi dağılımı.¶


- Model kurma;
1. Model kurma
1.1 Doğrusal Regresyon
1.2 Lojistik Regresyon
1.3 Destek Vektör Makinesi (SVM)
1.4 Karar Ağaçları

2.0 yapay sinir ağı ile model kurma.
2.1 Model sonucuna bakalım.
2.2 Model sonuçalarını görselleştirelim.

3.0 Veri setinden veri seçtirip ona rastgele tahmin yaptırma.
3.1 Seçilen değerlerini görselleştirelim.

- Sonuç
1. Sonuç değerlendirme.

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\realb\Desktop\yenilenebilir enerji kaynakları çalışması\data\complete_renewable_energy_dataset.csv")

# %% [markdown]
# ###  Veriye ilk bakış

# %% [markdown]
# ##### 1. Verinin ilk beş verisine bakış

# %%
df.head()
# Out:
#      Country  Year Energy Type  Production (GWh)  Installed Capacity (MW)  \
# 0        USA  2011       Solar      85404.690027              5549.794323
# 1  Australia  2008  Geothermal      22205.069382             43211.593798
# 2     Canada  2013     Biomass      94102.732038              6139.117212
# 3      Japan  2010     Biomass      88771.932910             40323.639260
# 4      China  2018       Solar      93288.408581             30755.403056
#
#    Investments (USD)  Population           GDP  Energy Consumption  \
# 0       5.604125e+09  1064007213  1.775278e+14       369654.644184
# 1       6.361886e+08  1033255852  6.435372e+13       771781.636293
# 2       6.158680e+09    14895124  1.567926e+14       342707.152899
# 3       8.526116e+09  1448827283  1.350464e+14       498839.574253
# 4       5.086237e+09  1499494307  8.677956e+13       819064.362785
#
#    Energy Exports  ...  Economic Freedom Index  Ease of Doing Business  \
# ...

# %% [markdown]
# ##### 2. Verinin son beş verisine bakış.

# %%
df.tail()
# Out:
#         Country  Year Energy Type  Production (GWh)  Installed Capacity (MW)  \
# 2495      Japan  2023       Solar      40091.199325             46650.085012
# 2496  Australia  2017       Hydro       9454.189177             28506.752159
# 2497      India  2022  Geothermal      94329.590380             22757.496947
# 2498      China  2000     Biomass      66206.311515              3530.005331
# 2499     France  2010       Hydro      13035.595344             22890.620016
#
#       Investments (USD)  Population           GDP  Energy Consumption  \
# 2495       5.589553e+09   819897975  1.110048e+14       574873.698448
# 2496       5.602669e+09   116522920  1.433965e+14       741594.182522
# 2497       8.590460e+09  1409070574  5.582925e+13       922633.984945
# 2498       5.640793e+09   859850706  2.147667e+13       481213.409793
# 2499       2.736650e+09   436771140  1.300406e+14       673214.512869
#
#       Energy Exports  ...  Economic Freedom Index  Ease of Doing Business  \
# ...

# %% [markdown]
# ##### 3. Veri seti hakkında ve indexler hakkında bilgi.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 56 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Country                                  2500 non-null   object
#  1   Year                                     2500 non-null   int64
#  2   Energy Type                              2500 non-null   object
#  3   Production (GWh)                         2500 non-null   float64
#  4   Installed Capacity (MW)                  2500 non-null   float64
#  5   Investments (USD)                        2500 non-null   float64
#  6   Population                               2500 non-null   int64
#  7   GDP                                      2500 non-null   float64
#  8   Energy Consumption                       2500 non-null   float64
#  9   Energy Exports                           2500 non-null   float64
# ...

# %% [markdown]
# ##### 4. Yapısal olrak veri ististiksel inceleme

# %%
df.describe().T
# Out:
#                                           count          mean           std  \
# Year                                     2500.0  2.011438e+03  6.895471e+00
# Production (GWh)                         2500.0  4.874320e+04  2.834092e+04
# Installed Capacity (MW)                  2500.0  2.488291e+04  1.446346e+04
# Investments (USD)                        2500.0  4.956155e+09  2.894789e+09
# Population                               2500.0  7.458927e+08  4.373146e+08
# GDP                                      2500.0  1.010745e+14  5.782363e+13
# Energy Consumption                       2500.0  4.957012e+05  2.914190e+05
# Energy Exports                           2500.0  5.014339e+04  2.883333e+04
# Energy Imports                           2500.0  5.080037e+04  2.874085e+04
# CO2 Emissions                            2500.0  4.912184e+05  2.897837e+05
# Renewable Energy Jobs                    2500.0  5.028961e+05  2.867490e+05
# ...

# %% [markdown]
# ##### 5. Veri setindeki ixdexler hakkında bilgi.

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Energy Type', 'Production (GWh)',
#        'Installed Capacity (MW)', 'Investments (USD)', 'Population', 'GDP',
#        'Energy Consumption', 'Energy Exports', 'Energy Imports',
#        'CO2 Emissions', 'Renewable Energy Jobs', 'Government Policies',
#        'R&D Expenditure', 'Renewable Energy Targets',
#        'Average Annual Temperature', 'Annual Rainfall', 'Solar Irradiance',
#        'Wind Speed', 'Hydro Potential', 'Geothermal Potential',
#        'Biomass Availability', 'Energy Storage Capacity',
#        'Grid Integration Capability', 'Electricity Prices', 'Energy Subsidies',
#        'International Aid for Renewables', 'Public Awareness',
#        'Energy Efficiency Programs', 'Urbanization Rate',
#        'Industrialization Rate', 'Energy Market Liberalization',
#        'Renewable Energy Patents', 'Educational Level',
#        'Technology Transfer Agreements', 'Renewable Energy Education Programs',
# ...

# %% [markdown]
# ##### 6. Veri setindeki boş veri varmı bakmak.

# %%
df.isnull().sum()
# Out:
# Country                                    0
# Year                                       0
# Energy Type                                0
# Production (GWh)                           0
# Installed Capacity (MW)                    0
# Investments (USD)                          0
# Population                                 0
# GDP                                        0
# Energy Consumption                         0
# Energy Exports                             0
# Energy Imports                             0
# CO2 Emissions                              0
# Renewable Energy Jobs                      0
# Government Policies                        0
# R&D Expenditure                            0
# Renewable Energy Targets                   0
# Average Annual Temperature                 0
# Annual Rainfall                            0
# Solar Irradiance                           0
# Wind Speed                                 0
# Hydro Potential                            0
# ...

# %% [markdown]
# ##### 7. Veri setindeki yapısal şekline bakalım.

# %%
df.shape
# Out:
# (2500, 56)

# %% [markdown]
# ###  Veri görselleştirme çalışmaları.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# ##### 1. Ülkelerin enerji üretim acısından inceleme.

# %%
# Ülkelerin enerji üretim acısından grafiği ele alalım.

sns.lineplot(x = "Country", y = "Energy Type", data = df);
plt.xticks(rotation = 90);
plt.grid(True)

# %% [markdown]
# - Burda ülkelerin ve enerji üretim şekli acısından bakalım.
#
# 1. Ülkeler acısından biyo kütle acısından bakıp bu ülkelerin bu tür acısından üretimlerine kıyasla Rusya ve Usa en yüksek üretimi yapmaktadır.

# %% [markdown]
# ##### 2. enerji üretim türleri ve buna bağlı üretim miktarı.

# %%
sns.lineplot(x = "Energy Type", y = "Production (GWh)", data = df);
plt.xticks(rotation = 90);
plt.grid(True)

# %% [markdown]
# - Enerji üretim türü ve üretim miktarı acısından bakaılm.
#
# 1. En fazla enerji üretimi biyokütle üretimi elde ediliyor.
# 2. En az enerji üretimini güney enerjisi üretimi ile üretilmektedir.

# %% [markdown]
# ##### 3. Ülkelerin enerji üretim miktarı ve üretim şekli acsından inceleme.

# %%
sns.boxplot(x = "Energy Type", y = "Production (GWh)", hue = "Country", data = df);
plt.xticks(rotation = 90);
plt.grid(True)

# Legend'i grafiğin dışına taşı
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left');

# %% [markdown]
# - Şimid burda ülkeleri üretim türü ve miktarı acısından inceleyelim.
#
# 1. Solar enerji türü bakımından en fazla üretim yapan ülkeler Japonya, Almanya ve Hindistan en fazla üretim yapanlşar. En az üretim yapanlar ise Kanada ve Avustralya. Burda az yapan üretim yapan ülkeler güneş alma süresi yıllık bazada az olan ülkeler olabilir örenğin kanada bir kuzey ülkesi ve güneş alması yıllık bazda az olabilir. Burda ilginç olan Avusturalya burda bu ülke güneş alma süresi oldukça iyi ama güneş enerjisi üretimi az burda ülke bunu politika haline gelirmemiş olabilir.
# 2. Geotermal burda en az üretim yapan ülke Japonya bu o ülkenin çoğrefya acısından o ülkenin Geotermal üretim acısından el verişli olmayabilir. En yüksek üretimi ise Almanya ve Çin yapmakta ve diğer ülkelere göre oldukça fazla.
# 3. Biyokütle üretim türü acısından en fazla üretim yapan ülke kanada bu üretim aslında sorunlu çünki bildiğimiz anblamda kömür yakmak ve enerji üretmek bu yüzden karbon salınımı bu üretim türlerinden en fazla üretim olanı ve ülkeler yavaş yavaş üretimini sürdürebilir üretime geçmekte Kanada bunu sanırım yapmıyor burda acıkça görünmekte. Burda en az üretim yapan Almanyayı ve Usa gerçekten tebrik edtmak gerekir sürdürülebilirlik kapsamında.
# 4. Rüzgar enerjisinden üretim burda bu en fazla üretim yapan ülkeler Usa, Hindistan, Fransa ve Rusya bu ülkeler ruzgar enerji üretimini oldukça iyi kullanmakta. En az üretim yapan ülkeler Brezilya ve Almanya bu acıdan Çoğafyanon bu üretime imkan verme acısıdan uygun fakat yine ülke politikası haline gelmeli.
# 4. Hidro enerji bu üretim tamamen çoğrefik imkanlara bağlı geniş düz çoğrafyaya sahip ülkelerin bu enerjiyi üretm imkanı yok burda Kanada ve Almanya üretimi oldukça yüksek Avusturalya üretimi az bunda çaoğrafyaya bağlamak lazım.
#
# - Burda önemli olan sürdürülebilir enerjilere genel olarak geçişi hala tam sağlanmadığını Örneğin Almanya ve Japonya bu işi yapmaya başlamış ve belli bir seviyeye gelmiş, üstelik bunlar sanayisi gelişmiş ülkeler ama bazı ülkeler gerçekten geride aklmış bunun kamoyunun dikkat etmesi gerekmektedir.

# %% [markdown]
# ##### 4. Ülkelerin enerji üretim miktarı ve kamu özel ortaklığı üretim acsından inceleme.

# %%
sns.boxplot(x = "Energy Type", y = "Production (GWh)", hue = "Public-Private Partnerships in Energy", data = df);
plt.xticks(rotation = 90);
plt.grid(True)

# Legend'i grafiğin dışına taşı
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left');

# %% [markdown]
# - Şimid bu çok ilginç. Genel olarak şunu bilelim biz insanlık olarak kazanma hırsı herşeyin önünde olan canlılarız ve en büyük zararı yine doğaya vermekteyiz şimid buna verilerle görelim.
#
# 1. Solar enerjide üretim kamu özel ortaklığı daha az enerji üretmiş kamuda.
# 2. Ruzgar enerjisidede bir fark göremiyorum.
#
# - Şimidi anlataçağım şeyi okuduktan sonra ne dediğimi daha iyi anlayaçaksınız. Kamu özel iş birşliği kamuda anında bütçeye yük olmasın diye özel firmalara ihale açıp saonrasında devletin yavaşça bu hizmeti halkına sağlaması.
# - Şimid gelelim sorunlu yere paris iklim anlaşmasından sonra ülkeleler yaşanan pandemi sonrasında sürdürebilirlik enerjiye geçişi hemen olmayaçağı için bunu yavaşça yapmaya karar verdiler ve bunu kamu özel iş birliği ile daha hızlı olaçağını söylediler eee grafik öyle demiyo halla güneş enerjisi gibi en önemli yeşil enerji neden devletler özalden daha fazla üretim sağlıyor.
# - Burda sorun o gün bu anlaşma katılan ülkeler avrupa ticari sahasından kredi yatırım ve ürünlerin pazar yeri bulmak için kabul etti ama halla net bir şekilde harekete geçişlmemiş.

# %% [markdown]
# ##### 5. Ülkelerin enerji üretim miktarı ve bçlgesel anlaşmalı üretim acsından inceleme.

# %%
sns.boxplot(x = "Energy Type", y = "Production (GWh)", hue = "Regional Renewable Energy Cooperation", data = df);
plt.xticks(rotation = 90);
plt.grid(True)

# Legend'i grafiğin dışına taşı
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left');

# %% [markdown]
# - İşte soruna esas çözüm ve daha yüksek başarı.
# - Bir üsteki grafikte kamu-özel iş birliğinin söylendiği kadar başarı sağlamadığını ama burda durum daha iyi.
#
# 1. Bakın güneş enerjisinde üretim net bölgesel anlaşmalarda daha yüksek.
# 2. Ruzgar enerjisindede durum aynı yine bölgeseler anlaşmalar üretim daha fazla.
#
# - Bu anlaşama genel anlamda kamu-özel anşlaşma acısından daha yüksek üretim sağlamış kamoyu bu biligi anlaşılmalı ve kamoyunda bu bilin ulaşmalı. Aksi takdirde bu lobilere bu kamu - özel anlaşmalar verilir ama bu anlaşmalar başarılıda olmamış.

# %% [markdown]
# ##### 6. Kurulu küç kapasitesine bakalım.

# %%
sns.boxplot(x = "Energy Type", y = "Installed Capacity (MW)", data = df);
plt.xticks(rotation = 90);
plt.grid(True);

# Legend'i grafiğin dışına taşı
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left');
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# - tatal üretim kapesitesi kapsamında bakalım.
#
# 1. En yüksek biokütle ve geotermal üretim acısından en yüksek üretim kapesitesine sahip.
# 2. En düşük üretim kapesitesi kapsamı acısından güneş enerjisi kapsamından bu şekilde en düşük güneş enerjisi.

# %% [markdown]
# ##### 7. Üretim kapesitesinin ülkeler acısından.

# %%
sns.boxplot(x = "Energy Type", y = "Installed Capacity (MW)", hue = "Country", data = df);
plt.xticks(rotation = 90);
plt.grid(True);

# Legend'i grafiğin dışına taşı
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left');

# %% [markdown]
# - Ülkelerin üretim kapesitesi kapsamında ele alıp bakalım.
#
# 1. Güneş enerjisi üretim kapasitesi bakımında en yüksek üretim kapesitesi Fransaya ait ama üretim bakımından en fazla değil buda yüksek verim göstermediğini gösterir. En düşük üretim kapesitesine ait yatırımı yapan ülke ise Brezilya.
# 2. Jeotermal üretim kapesitesi bakımından üretilen kapesite acısından en yüksek üretimn kapesitesine ait ülke Brezilya ama Brezilya en yüksek üretim yapan ülke değil. BUrda yine üretim verimi acısından yine bir sorun olduğu görünmekte.
# 3. Biokütle eritim acısından en yüksek üretimi yapan ülke Çin ve Usa görünmekte burda Çin sanayide yükselişi ve bunun b*neticesinde enerji kaynaklarına yetişteremeyip yenilemeyen üretim kaynağı kapsamından üretim yapıyor.
# 4. Rüzgar enerjisi kapsamından en yüksek üretim acısında sahip ülkeler Fransa ve Kanadaya sahip.
# 5. Hirdo enerji üretim kapesitresine sahip ülkeler kapsamından bakınca Almanya en yüksek üretime sahip iken en düşük üretim kapesitesi neticesinde en düşük üretim Kanadada buda yine çoğrafyaya uyumlukuk acısından olabilir.
#
# - Burda siyasi bir sonuç göremnkteyim Rusya-Ukranya savası neticesinde avrupa ülkeleri üretimi güneş ve ruzgara cevirdiği doğru ama burda en fazla üretime yatırım yapan ülke Fransa. Almanya burda tam olrak gerekli dönüşümü yapamış gibi görünüyor.

# %% [markdown]
# ##### 8. Fransa özelinde Rusya - Ukaranya savaşı sonrası Fransanın üretim kapesitesini artırmada nasıl bir politika yapmış ona balaım.

# %%
# Veriyi Fransa'ya göre filtreleyin
df_france = df[df['Country'] == 'France']

# Boxplot'u oluşturun
sns.boxplot(x="Energy Type", y="Installed Capacity (MW)", hue="Public-Private Partnerships in Energy", data=df_france)
plt.xticks(rotation=90)
plt.grid(True)

# Legend'i grafiğin dışına taşı
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# %%
# Veriyi Fransa'ya göre filtreleyin
df_france = df[df['Country'] == 'France']

# Boxplot'u oluşturun
sns.boxplot(x="Energy Type", y="Installed Capacity (MW)", hue="Regional Renewable Energy Cooperation", data=df_france)
plt.xticks(rotation=90)
plt.grid(True)

# Legend'i grafiğin dışına taşı
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# %% [markdown]
# - Şimdi üretim kapesitesi ve üretilen miktar ve bunların projelendirilmesine bakaçağız.
#
# 1. Biliyoruzki kamu-özel oretklığı üretimin bölglere özel üretimden verim kaynağı daha düşük olduğunu biliyoruz.
# 2. Fransa üretim miktarı kapsamından en fazla üretim olması ama o kadar fazla üretim yapamamsının sebebi ise burda prjelendirme odaklı olabilir. Büyük bir kısmını kamu - özel ile yapılmış buda verim düşük olmasına sebeb olabilir.
#
# - Savaş ve boykot bazı şeyler için bahane olmuş olabilir.

# %% [markdown]
# ##### 9. Üretim kapesityesi ve yıl odaklı bakalım şimdide.

# %%
sns.boxplot(x = "Year", y = "Production (GWh)", data = df);
plt.xticks(rotation = 90);
plt.grid(True);

# Legend'i grafiğin dışına taşı
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left');
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# - Üretim ve yıllara göre genel dağılımı acısından bakalım.
#
# 1. Burda yıllara göre artışta linner bir artış yok 2013, 2008 ve 2019 de en fazla artış göstermekte.

# %% [markdown]
# ##### 10. Burda yıllara ve üretim miktarı ve bunun hangi tür üretim ile olduğuna bakılm.

# %%
plt.figure(figsize=(45,20))

sns.boxplot(x = "Year", y = "Production (GWh)", hue = "Energy Type", data = df);
plt.xticks(rotation = 90, fontsize = 20);
plt.yticks(fontsize = 20);
plt.grid(True);

# Legend'i grafiğin dışına taşı ve yazı tipini büyüt
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop={'size': 25})

# %% [markdown]
# # Yıllara Göre Enerji Üretim Türlerinin Analizi
#
# Grafikte yıllara göre enerji üretim türlerinin kurulu kapasite değerlerine bakarak, her yıl en yüksek üretim kapasitesine sahip olan enerji türünü tek tek yorumlayalım:
#
# ### 2000:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - Hidroelektrik enerjisi, 2000 yılında diğer enerji türlerine göre en yüksek üretim kapasitesine sahip.
#
# ### 2001:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - 2001 yılında da hidroelektrik enerji en yüksek üretim kapasitesine sahip enerji türü olarak öne çıkıyor.
#
# ### 2002:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - Hidroelektrik enerji, 2002 yılında yine en yüksek kapasite ile üretim yapan enerji türü.
#
# ### 2003:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - 2003 yılında da hidroelektrik enerji diğer enerji türlerinden daha yüksek bir üretim kapasitesine sahip.
#
# ### 2004:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - Hidroelektrik enerji 2004 yılında da en yüksek üretim kapasitesine sahip.
#
# ### 2005:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - 2005 yılında hidroelektrik enerji yine en yüksek üretim kapasitesine sahip.
#
# ### 2006:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - 2006 yılında da hidroelektrik enerji diğer türlerden daha yüksek üretim kapasitesine sahip.
#
# ### 2007:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - Hidroelektrik enerji 2007 yılında en yüksek kapasite ile üretim yapan enerji türü olarak öne çıkıyor.
#
# ### 2008:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - 2008 yılında da hidroelektrik enerji en yüksek üretim kapasitesine sahip.
#
# ### 2009:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - Hidroelektrik enerji 2009 yılında en yüksek kapasite ile üretim yapmaya devam ediyor.
#
# ### 2010:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - 2010 yılında da hidroelektrik enerji en yüksek üretim kapasitesine sahip.
#
# ### 2011:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - Hidroelektrik enerji 2011 yılında da diğer türlerden daha yüksek üretim kapasitesine sahip.
#
# ### 2012:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - 2012 yılında hidroelektrik enerji yine en yüksek kapasite ile üretim yapan enerji türü.
#
# ### 2013:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - 2013 yılında da hidroelektrik enerji en yüksek üretim kapasitesine sahip.
#
# ### 2014:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - 2014 yılında hidroelektrik enerji en yüksek üretim kapasitesine sahip enerji türü.
#
# ### 2015:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - Hidroelektrik enerji, 2015 yılında da en yüksek kapasite ile üretim yapan enerji türü.
#
# ### 2016:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - 2016 yılında da hidroelektrik enerji en yüksek üretim kapasitesine sahip.
#
# ### 2017:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - Hidroelektrik enerji, 2017 yılında en yüksek kapasite ile üretim yapan enerji türü olarak öne çıkıyor.
#
# ### 2018:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - 2018 yılında da hidroelektrik enerji diğer türlere göre en yüksek üretim kapasitesine sahip.
#
# ### 2019:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - 2019 yılında hidroelektrik enerji en yüksek üretim kapasitesine sahip.
#
# ### 2020:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - 2020 yılında da hidroelektrik enerji en yüksek kapasite ile üretim yapıyor.
#
# ### 2021:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - 2021 yılında da en yüksek üretim kapasitesi hidroelektrik enerji türünde.
#
# ### 2022:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - 2022 yılında da hidroelektrik enerji en yüksek üretim kapasitesine sahip enerji türü.
#
# ### 2023:
# - **En yüksek enerji üretim türü:** Hidroelektrik
#   - Hidroelektrik enerji, 2023 yılında da en yüksek kapasite ile üretim yapan enerji türü olarak öne çıkıyor.
#
# ## Sonuç:
# Her yıl için hidroelektrik enerji, en yüksek kurulu kapasiteye sahip enerji türü olarak dikkat çekiyor. Bu, hidroelektrik enerjinin yıllar boyunca enerji üretiminde baskın bir rol oynadığını gösteriyor. Diğer enerji türleri, özellikle rüzgar enerjisi, bazı yıllarda belirgin artışlar gösterse de, hidroelektrik enerji her zaman öne çıkan enerji türü olarak kalmış.

# %% [markdown]
# ##### 11. Üretim kapesitesi bakımından yıllara ve üretim türlerine göre bakılm.

# %%
plt.figure(figsize=(45,20))

sns.boxplot(x = "Year", y = "Production (GWh)", hue = "Energy Type", data = df);
plt.xticks(rotation = 90, fontsize = 20);
plt.yticks(fontsize = 20);
plt.grid(True);

# Legend'i grafiğin dışına taşı ve yazı tipini büyüt
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop={'size': 25});

# %% [markdown]
# - Genel değişim oenı şekilinde yıllara dağılımı şeklinde bakalım.
#
# 1. Güneş Enerjisi (Solar): 2002’den 2009’a kadar güneş enerjisi üretimi artmış gibi görünüyor.
# 2. Jeotermal Enerji (Geothermal): 2004’ten 2006’ya kadar jeotermal enerji üretimi nispeten sabit kalmış gibi görünüyor.
# 3. Biyokütle Enerjisi (Biomass): 2002’den 2009’a kadar biyokütle enerjisi üretimi artmış gibi görünüyor.
# 4. Rüzgar Enerjisi (Wind): 2002’den 2009’a kadar rüzgar enerjisi üretimi büyük bir artış göstermiş gibi görünüyor.
# 5. Hidroelektrik Enerjisi (Hydro): 2002’den 2009’a kadar hidroelektrik enerjisi üretimi nispeten sabit kalmış gibi görünüyor.

# %% [markdown]
# ##### 12. Enerji tüketimine bakalım yıllara göre.

# %%
plt.figure(figsize=(45,20));

# Box plot oluştur
sns.boxplot(x="Year", y="Energy Consumption", data=df)

# X ve Y eksenindeki yazıları büyüt
plt.xticks(rotation=90, fontsize=24)  # X eksenindeki yazılar için
plt.yticks(fontsize=24)  # Y eksenindeki yazılar için

# Gridline ekle
plt.grid(True)

# Eksen etiketlerini ve başlığı ekle
plt.xlabel('Year', fontsize=26)
plt.ylabel('Energy Consumption', fontsize=26)
plt.title('Energy Consumption by Year', fontsize=28)

# Legend'i grafiğin dışına taşı ve yazı tipini büyüt
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop={'size': 25});
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# - Üretim miktarı yıllara göre nasıl değişmiş. 2009-2013 arasına bakacağım çünki daha gerisi yanıltıcı olabilir.
#
# 1. 2009: Bu yıl enerji tüketimi düşük seviyede başlamış gibi görünüyor.
# 2. 2010: Enerji tüketimi hafifçe artmış gibi görünüyor.
# 3. 2011: Artış devam ediyor, ancak hala 2009 seviyelerinin altında.
# 4. 2012: Enerji tüketimi daha da artmış gibi görünüyor.
# 5. 2013: Bu yıl, enerji tüketimi önemli ölçüde artmış gibi görünüyor.
# 6. 2014: Enerji tüketimi yine yükselişte.
# 7. 2015: Stabil bir seviyede görünüyor.
# 8. 2016: Enerji tüketimi hafifçe düşmüş gibi görünüyor.
# 9. 2017: Bu yıl, enerji tüketimi biraz daha düşük.
# 10. 2018: Enerji tüketimi yine artmış gibi görünüyor.
# 11. 2019: Stabil bir seviyede devam ediyor.
# 12. 2020: Enerji tüketimi hafifçe düşmüş gibi görünüyor.
# 13. 2021: Bu yıl, enerji tüketimi biraz daha düşük.

# %% [markdown]
# ##### 13. Enerji tüketimine bakalım yıllara göre ve enerji üretim türleri acısından bakaılm.

# %%
plt.figure(figsize=(50,20));

# Box plot oluştur
sns.boxplot(x="Year", y="Energy Consumption", hue = "Energy Type", data=df)

# X ve Y eksenindeki yazıları büyüt
plt.xticks(rotation=90, fontsize=24)  # X eksenindeki yazılar için
plt.yticks(fontsize=24)  # Y eksenindeki yazılar için

# Gridline ekle
plt.grid(True)

# Eksen etiketlerini ve başlığı ekle
plt.xlabel('Year', fontsize=26)
plt.ylabel('Energy Consumption', fontsize=26)
plt.title('Energy Consumption by Year', fontsize=28)

# Legend'i grafiğin dışına taşı ve yazı tipini büyüt
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop={'size': 25});

# %% [markdown]
# - Yıllara göre enerji tüketim ve bunun üretim türü şekilnden bakalım.
#
# 1. 2008 de tüketilen elektiriğin solar enerji üzerinden tüketimi çok az.
# 2. 2018 de ise tüketilen ebnerjinin büyük kısmı ruzgar enerjisinden kaynaklı.
# 3. Yine 2008 de en fazla tüketilen enerjinin en büyük kısmı ruzgar enerjisinden üretiliyor.
# 4. Son yıllarda genelde yenilebilir elektirik üretiminde bir artış soz konusu ama hala bio kütle doğan enerji tüketimide oldukça yüksek.

# %% [markdown]
# ##### 14. Yıllara göre göre yenilebilir enerji oranı.

# %%
plt.figure(figsize=(50,20));

# Box plot oluştur
sns.boxplot(x="Year", y="Proportion of Energy from Renewables", data=df)

# X ve Y eksenindeki yazıları büyüt
plt.xticks(rotation=90, fontsize=24)  # X eksenindeki yazılar için
plt.yticks(fontsize=24)  # Y eksenindeki yazılar için

# Gridline ekle
plt.grid(True)

# Eksen etiketlerini ve başlığı ekle
plt.xlabel('Year', fontsize=26)
plt.ylabel('Energy Consumption', fontsize=26)
plt.title('Energy Consumption by Year', fontsize=28)

# Legend'i grafiğin dışına taşı ve yazı tipini büyüt
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop={'size': 25});
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# - Yıllara göre enerji üretim oranı.
#
# 1. Evet şunu söyleyebilirimki durum çok aydınlık değil.
# 2. Genel olrak 2010 lardan sonra bir şekilde yenilebilir enerji kaynaklarına bir akım şeklinde artış var. Ama son yıllarda enerji tüketimininde artışıyla bu alanda yeterli yatırım olmamamsı genel oranda bir düşüşe neden olmuş olabilir.
# 3. Çok ilginç 2024 yılında 2000 yılına göre orantısal bazda daha fazla üretim olmuş.
# 4. İşte bu gerçekten ilginç.

# %% [markdown]
# ##### 15. Yıllara göre göre yenilebilir enerji oranını ülkelere odaklı inceleme.

# %%
plt.figure(figsize=(180,90));

# Box plot oluştur
sns.boxplot(x="Year", y="Proportion of Energy from Renewables", hue = "Country",  data=df)

# X ve Y eksenindeki yazıları büyüt
plt.xticks(rotation=90, fontsize=150)  # X eksenindeki yazılar için
plt.yticks(fontsize=150)  # Y eksenindeki yazılar için

# Gridline ekle
plt.grid(True)

# Legend'i grafiğin dışına taşı ve yazı tipini büyüt
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop={'size': 100});

# %% [markdown]
# - Bu garfik karmaşık ama iki önemli detay var onu paylaşmak için grafiği oluşturuyorum.
#
# 1. 2001 de almanyanın yenileblir enerji kaynağı üretimi çok yüksek.
# 2. 2014 de avurturalya nın yenilenebilir enerji kaynağı üretimi geçen yıllara göre çok artmış.

# %% [markdown]
# ##### 16. Bu grafikte yenilebilir enerji kaynakları acısından ülkeleri 2023 yılı için inceleyelim.

# %%
# 2024 yılına odaklanarak veriyi filtrele
df_2024 = df[df['Year'] == 2023]

plt.figure(figsize=(20,10));

# Box plot oluştur
sns.boxplot(x="Country", y="Proportion of Energy from Renewables",  data=df)

# X ve Y eksenindeki yazıları büyüt
plt.xticks(rotation=90, fontsize=15)  # X eksenindeki yazılar için
plt.yticks(fontsize=15)  # Y eksenindeki yazılar için

# Gridline ekle
plt.grid(True)

# Legend'i grafiğin dışına taşı ve yazı tipini büyüt
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop={'size': 10});
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# - Burda ülkelerin yenilebilir enerji kaynağı oranına bakıyorum ama sadece 2023 yıllı için bakalım.
#
# 1. Burda en yüksek üretimi olan ülke avusturalya.
# 2. Burda en düşük üretim olan ülke ise Brezilya.

# %% [markdown]
# ##### 17. Yenilebilir enerji kaynaklarının oranı ve bunların yapılma proje anlaşmaları.

# %%
# kamu ve özel olarak yapılan projeler.

# 2024 yılına odaklanarak veriyi filtrele
df_2024 = df[df['Year'] == 2023]

plt.figure(figsize=(20,10));

# Box plot oluştur
sns.boxplot(x="Country", y="Proportion of Energy from Renewables", hue = "Public-Private Partnerships in Energy", data=df)

# X ve Y eksenindeki yazıları büyüt
plt.xticks(rotation=90, fontsize=15)  # X eksenindeki yazılar için
plt.yticks(fontsize=15)  # Y eksenindeki yazılar için

# Gridline ekle
plt.grid(True)

# Legend'i grafiğin dışına taşı ve yazı tipini büyüt
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop={'size': 10});

# %%
# Bölgesel anlaşamalara göre yapılan projeler.

# 2024 yılına odaklanarak veriyi filtrele
df_2024 = df[df['Year'] == 2023]

plt.figure(figsize=(20,10));

# Box plot oluştur
sns.boxplot(x="Country", y="Proportion of Energy from Renewables", hue = "Regional Renewable Energy Cooperation", data=df)

# X ve Y eksenindeki yazıları büyüt
plt.xticks(rotation=90, fontsize=15)  # X eksenindeki yazılar için
plt.yticks(fontsize=15)  # Y eksenindeki yazılar için

# Gridline ekle
plt.grid(True)

# Legend'i grafiğin dışına taşı ve yazı tipini büyüt
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop={'size': 10});

# %% [markdown]
# ##### 18. kişi başına düşen milli gelir ve enerji üretimi dağılımı.

# %%
# 2024 yılına odaklanarak veriyi filtrele
df_2024 = df[df['Year'] == 2023]

plt.figure(figsize=(20,10));

# Box plot oluştur
sns.boxplot(x="Country", y="GDP", hue = "Energy Type", data=df)

# X ve Y eksenindeki yazıları büyüt
plt.xticks(rotation=90, fontsize=15)  # X eksenindeki yazılar için
plt.yticks(fontsize=15)  # Y eksenindeki yazılar için

# Gridline ekle
plt.grid(True)

# Legend'i grafiğin dışına taşı ve yazı tipini büyüt
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop={'size': 10});

# %% [markdown]
# ### Model kurma

# %% [markdown]
# ##### 1. Model kurma

# %% [markdown]
# ##### 1.1 Doğrusal Regresyon

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression 
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, classification_report, confusion_matrix, accuracy_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %%
# Yalnızca özellik ve hedef değişkenleri tanımlayın
X = df.drop('Proportion of Energy from Renewables', axis=1)
y = df['Proportion of Energy from Renewables']

# Kategorik ve sayısal sütunları ayırın
categorical_features = X.select_dtypes(include=['object']).columns
numerical_features = X.select_dtypes(exclude=['object']).columns

# Kategorik veriler için OneHotEncoder, sayısal veriler için StandardScaler kullanacağız
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(), categorical_features)
    ])

# Veriyi eğitim ve test setlerine ayır
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Model pipeline'ını oluştur
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# Modeli eğitim verileri ile eğit
model.fit(X_train, y_train)

# Test verileri ile tahmin yap
y_pred = model.predict(X_test)

# %%
# Performans metriklerini hesapla
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R2): {r2:.2f}")
# Out:
# Mean Squared Error (MSE): 851.25
# Root Mean Squared Error (RMSE): 29.18
# Mean Absolute Error (MAE): 24.91
# R-squared (R2): -0.05

# %%
plt.figure(figsize=(14, 6))

# Tahminlerin ve Gerçek Değerlerin Dağılımı
plt.subplot(1, 2, 1)
sns.histplot(y_pred, color='blue', label='Tahmin Edilen', kde=True)
sns.histplot(y_test, color='orange', label='Gerçek', kde=True)
plt.xlabel('Proportion of Energy from Renewables')
plt.ylabel('Frekans')
plt.title('Tahmin ve Gerçek Değerlerin Dağılımı')
plt.legend()

# Hata Histogramı
plt.subplot(1, 2, 2)
plt.hist(errors, bins=30, color='coral', edgecolor='black')
plt.xlabel('Hata', fontsize=14)
plt.ylabel('Frekans', fontsize=14)
plt.title('Tahmin Hatalarının Histogramı', fontsize=16)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1.2 Lojistik Regresyon

# %%
# Eşik değeri belirleme (örneğin, %50)
threshold = 0.5
y_class = (df['Proportion of Energy from Renewables'] > threshold).astype(int)

# Yalnızca özellik ve hedef değişkenleri tanımlayın
X = df.drop('Proportion of Energy from Renewables', axis=1)
y = y_class

# Kategorik ve sayısal sütunları ayırın
categorical_features = X.select_dtypes(include=['object']).columns
numerical_features = X.select_dtypes(exclude=['object']).columns

# Kategorik veriler için OneHotEncoder, sayısal veriler için StandardScaler kullanacağız
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(), categorical_features)
    ])

# Veriyi eğitim ve test setlerine ayır
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Model pipeline'ını oluştur
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression(max_iter=1000))
])

# Modeli eğitim verileri ile eğit
model.fit(X_train, y_train)

# Test verileri ile tahmin yap
y_pred = model.predict(X_test)

# %%
# Performans metriklerini hesapla
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy:.2f}")
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(class_report)
# Out:
# Accuracy: 0.99
# Confusion Matrix:
# [[  0   3]
#  [  0 497]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.99      1.00      1.00       497
#
#     accuracy                           0.99       500
#    macro avg       0.50      0.50      0.50       500
# weighted avg       0.99      0.99      0.99       500

# %%
plt.figure(figsize=(12, 6))

# Performans Metrikleri Bar Grafiği (Lojistik Regresyon için sadece doğruluk gösterebiliriz)
plt.subplot(1, 2, 1)
plt.bar(['Accuracy'], [accuracy], color='blue', edgecolor='black')
plt.xlabel('Performans Metrikleri', fontsize=14)
plt.ylabel('Değer', fontsize=14)
plt.title('Model Performans Metrikleri', fontsize=16)

# Confusion Matrix Görselleştirilmesi
plt.subplot(1, 2, 2)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Tahmin Edilen Etiket', fontsize=14)
plt.ylabel('Gerçek Etiket', fontsize=14)
plt.title('Confusion Matrix', fontsize=16)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1.3 Destek Vektör Makinesi (SVM)

# %%
# Eşik değeri belirleme (örneğin, %50)
threshold = 0.5
y_class = (df['Proportion of Energy from Renewables'] > threshold).astype(int)

# Yalnızca özellik ve hedef değişkenleri tanımlayın
X = df.drop('Proportion of Energy from Renewables', axis=1)
y = y_class

# Kategorik ve sayısal sütunları ayırın
categorical_features = X.select_dtypes(include=['object']).columns
numerical_features = X.select_dtypes(exclude=['object']).columns

# Kategorik veriler için OneHotEncoder, sayısal veriler için StandardScaler kullanacağız
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(), categorical_features)
    ])

# Veriyi eğitim ve test setlerine ayır
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Model pipeline'ını oluştur
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', SVC(kernel='linear'))  # Lineer çekirdek kullanarak SVM modeli oluşturuyoruz
])

# Modeli eğitim verileri ile eğit
model.fit(X_train, y_train)

# Test verileri ile tahmin yap
y_pred = model.predict(X_test)

# %%
# Performans metriklerini hesapla
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy:.2f}")
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(class_report)
# Out:
# Accuracy: 0.99
# Confusion Matrix:
# [[  0   3]
#  [  0 497]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.99      1.00      1.00       497
#
#     accuracy                           0.99       500
#    macro avg       0.50      0.50      0.50       500
# weighted avg       0.99      0.99      0.99       500

# %%
plt.figure(figsize=(12, 6))

# Performans Metrikleri Bar Grafiği (SVM için sadece doğruluk gösterebiliriz)
plt.subplot(1, 2, 1)
plt.bar(['Accuracy'], [accuracy], color='blue', edgecolor='black')
plt.xlabel('Performans Metrikleri', fontsize=14)
plt.ylabel('Değer', fontsize=14)
plt.title('Model Performans Metrikleri', fontsize=16)

# Confusion Matrix Görselleştirilmesi
plt.subplot(1, 2, 2)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Tahmin Edilen Etiket', fontsize=14)
plt.ylabel('Gerçek Etiket', fontsize=14)
plt.title('Confusion Matrix', fontsize=16)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1.4 Karar Ağaçları

# %%
# Eşik değeri belirleme (örneğin, %50)
threshold = 0.5
y_class = (df['Proportion of Energy from Renewables'] > threshold).astype(int)

# Yalnızca özellik ve hedef değişkenleri tanımlayın
X = df.drop('Proportion of Energy from Renewables', axis=1)
y = y_class

# Kategorik ve sayısal sütunları ayırın
categorical_features = X.select_dtypes(include=['object']).columns
numerical_features = X.select_dtypes(exclude=['object']).columns

# Kategorik veriler için OneHotEncoder, sayısal veriler için StandardScaler kullanacağız
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(), categorical_features)
    ])

# Veriyi eğitim ve test setlerine ayır
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Model pipeline'ını oluştur
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', DecisionTreeClassifier(random_state=0))
])

# Modeli eğitim verileri ile eğit
model.fit(X_train, y_train)

# Test verileri ile tahmin yap
y_pred = model.predict(X_test)

# %%
# Performans metriklerini hesapla
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy:.2f}")
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(class_report)
# Out:
# Accuracy: 0.99
# Confusion Matrix:
# [[  0   3]
#  [  2 495]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.99      1.00      0.99       497
#
#     accuracy                           0.99       500
#    macro avg       0.50      0.50      0.50       500
# weighted avg       0.99      0.99      0.99       500

# %%
plt.figure(figsize=(12, 6))

# Performans Metrikleri Bar Grafiği (Karar Ağaçları için sadece doğruluk gösterebiliriz)
plt.subplot(1, 2, 1)
plt.bar(['Accuracy'], [accuracy], color='blue', edgecolor='black')
plt.xlabel('Performans Metrikleri', fontsize=14)
plt.ylabel('Değer', fontsize=14)
plt.title('Model Performans Metrikleri', fontsize=16)

# Confusion Matrix Görselleştirilmesi
plt.subplot(1, 2, 2)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Tahmin Edilen Etiket', fontsize=14)
plt.ylabel('Gerçek Etiket', fontsize=14)
plt.title('Confusion Matrix', fontsize=16)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Burda makine öğrenmesi modelleri benzeklik gösteriyor ama ben burda yapay sinir ağı ile kurulan mnodelin daha baarılı olcağına karar verdim ve hihayi modeli yapay sinir ağları seklinde olcak şekilde kurmaya karar verdim.

# %% [markdown]
# ##### 2.0 yapay sinir ağı ile model kurma.

# %%
# Define X and y
X = df.drop(columns=['Proportion of Energy from Renewables'])
y = df['Proportion of Energy from Renewables']

# Define categorical columns
categorical_cols = X.select_dtypes(include=['object']).columns

# Define preprocessing for numerical and categorical columns
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), X.select_dtypes(include=[np.number]).columns),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
    ])

# Preprocess the data
X_processed = preprocessor.fit_transform(X)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_processed, y, test_size=0.2, random_state=42)

# Normalize the target variable
scaler_y = StandardScaler()
y_train = scaler_y.fit_transform(y_train.values.reshape(-1, 1)).flatten()
y_test = scaler_y.transform(y_test.values.reshape(-1, 1)).flatten()

# %%
# Build the neural network model
model = Sequential()
model.add(Dense(256, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='linear'))  # Regression task

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 1s 3ms/step - loss: 1.0547 - val_loss: 1.0097
# Epoch 2/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8755 - val_loss: 1.0955
# Epoch 3/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7266 - val_loss: 1.1184
# Epoch 4/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5536 - val_loss: 1.1645
# Epoch 5/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3363 - val_loss: 1.2965
# Epoch 6/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1838 - val_loss: 1.3620
# Epoch 7/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0925 - val_loss: 1.4107
# Epoch 8/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0493 - val_loss: 1.3881
# Epoch 9/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0287 - val_loss: 1.3875
# Epoch 10/50
# ...

# %% [markdown]
# ##### 2.1 Model sonucuna bakalım.

# %%
# Predict on test set
y_pred = model.predict(X_test)

# Inverse transform the predictions and true values
y_pred_inv = scaler_y.inverse_transform(y_pred).flatten()
y_test_inv = scaler_y.inverse_transform(y_test.reshape(-1, 1)).flatten()

# Calculate the mean squared error and other metrics
mse = np.mean((y_test_inv - y_pred_inv) ** 2)
print(f"Mean Squared Error: {mse}")
# Out:
# 16/16 [==============================] - 0s 733us/step
# Mean Squared Error: 1103.9130038927476

# %% [markdown]
# ##### 2.2 Model sonuçalarını görselleştirelim.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Real vs Predicted plot
plt.subplot(1, 2, 1)
plt.scatter(y_test_inv, y_pred_inv, alpha=0.5)
plt.xlabel('Real Proportion of Energy from Renewables')
plt.ylabel('Predicted Proportion of Energy from Renewables')
plt.title('Real vs Predicted')

# Histogram of errors
plt.subplot(1, 2, 2)
errors = y_pred_inv - y_test_inv
plt.hist(errors, bins=50)
plt.xlabel('Error')
plt.ylabel('Frequency')
plt.title('Prediction Errors')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 3.0 Veri setinden veri seçtirip ona rastgele tahmin yaptırma.

# %%
import random

# Orijinal veri kümesinden rastgele bir örnek seçin (hedef değişken hariç)
random_index = random.randint(0, len(df) - 1)
random_sample = df.drop(columns=['Proportion of Energy from Renewables']).iloc[[random_index]]

# Seçilen rastgele örneği göster
print("Selected Random Sample:")
print(random_sample)
# Out:
# Selected Random Sample:
#      Country  Year Energy Type  Production (GWh)  Installed Capacity (MW)  \
# 1427  Canada  2023  Geothermal      77626.961734             10393.307754
#
#       Investments (USD)  Population           GDP  Energy Consumption  \
# 1427       4.991930e+09  1050246229  4.288603e+13       827739.038629
#
#       Energy Exports  ...  Control of Corruption  Economic Freedom Index  \
# 1427    90841.141034  ...                3.78361                96.28015
#
#       Ease of Doing Business  Innovation Index  \
# 1427               13.403819         67.369668
#
#       Number of Research Institutions  Number of Renewable Energy Conferences  \
# 1427                              267                                      22
#
#       Number of Renewable Energy Publications  Energy Sector Workforce  \
# 1427                                     8869                   964270
#
#       Public-Private Partnerships in Energy  \
# ...

# %%
# Seçilen numuneyi ön işleme tabi tutun
random_sample_processed = preprocessor.transform(random_sample)

# %%
# Eğitilen modeli kullanarak tahminde bulunun
predicted_value = model.predict(random_sample_processed)

# Orijinal ölçeği elde etmek için tahmini ters dönüştürün
predicted_value_inv = scaler_y.inverse_transform(predicted_value).flatten()

print(f"Predicted Proportion of Energy from Renewables: {predicted_value_inv[0]}")
# Out:
# 1/1 [==============================] - 0s 16ms/step
# Predicted Proportion of Energy from Renewables: 90.15545654296875

# %%
# Gerçek değeri al
actual_value = df['Proportion of Energy from Renewables'].iloc[random_index]

print(f"Actual Proportion of Energy from Renewables: {actual_value}")
# Out:
# Actual Proportion of Energy from Renewables: 84.3303498232809

# %% [markdown]
# ##### 3.1 Seçilen değerlerini görselleştirelim.

# %%
# Tahmin ve gerçek değerleri içeren bir DataFrame oluştur
comparison_df = pd.DataFrame({
    'Type': ['Predicted', 'Actual'],
    'Value': [predicted_value_inv[0], actual_value]
})

# Görselleştirme
plt.figure(figsize=(8, 6))
sns.barplot(x='Type', y='Value', data=comparison_df, palette='viridis')
plt.title('Yenilenebilir Kaynaklardan Elde Edilen Enerjinin Tahmin Edilen ve Gerçek Oranlarının Karşılaştırılması')
plt.xlabel('Tip')
plt.ylabel('Yenilenebilir Kaynaklardan Gelen Enerjinin Oranı')
plt.show()

# %% [markdown]
# ###  Sonuç.

# %% [markdown]
# ##### 1. Sonuç değerlendirme.

# %% [markdown]
# # Proje Genel Açıklaması
#
# ## 1. Veriye İlk Bakış:
#
# - **1.1 Verinin İlk Beş Verisine Bakış:**
#   Veri setinin ilk beş verisi, verinin yapısını ve temel özelliklerini hızlıca anlamak için kullanılır. Bu, veri setinin genel içeriği hakkında bir fikir edinmenizi sağlar.
#
# - **1.2 Verinin Son Beş Verisine Bakış:**
#   Verinin son beş verisini incelemek, veri setinin sonundaki değerlerin de nasıl göründüğünü ve herhangi bir anomali olup olmadığını kontrol etmenizi sağlar.
#
# - **1.3 Veri Seti Hakkında ve İndeksler Hakkında Bilgi:**
#   Veri setinin yapısal özelliklerini ve indeksleri hakkında bilgi almak, veri setindeki verilerin nasıl düzenlendiğini ve erişildiğini anlamanızı sağlar.
#
# - **1.4 Yapısal Olarak Veri İstatistiksel İnceleme:**
#   Veri setinin temel istatistiklerini (ortalama, medyan, standart sapma vb.) incelemek, verinin dağılımı ve varyasyonları hakkında bilgi sağlar.
#
# - **1.5 Veri Setindeki İndeksler Hakkında Bilgi:**
#   İndekslerin ne tür bilgileri temsil ettiğini ve veri setindeki her bir satırın anlamını anlamak, veri analizi sürecinde önemli bir adımdır.
#
# - **1.6 Veri Setindeki Boş Veriler Var mı Bakmak:**
#   Veri setinde eksik değerler olup olmadığını kontrol etmek, eksik veri ile başa çıkma stratejilerini belirlemek için gereklidir.
#
# - **1.7 Veri Setindeki Yapısal Şekline Bakalım:**
#   Veri setinin yapısal özelliklerini incelemek, veri türleri, sütun sayısı ve veri formatları hakkında bilgi sağlar.
#
# ## 2. Veri Görselleştirmesi:
#
# - **2.1 Ülkelerin Enerji Üretimi Açısından İnceleme:**
#   Ülkelerin enerji üretim kapasitelerini ve miktarlarını incelemek, enerji üretimindeki genel eğilimleri anlamanıza yardımcı olur.
#
# - **2.2 Enerji Üretim Türleri ve Buna Bağlı Üretim Miktarı:**
#   Farklı enerji üretim türlerinin ne kadar enerji ürettiğini görselleştirmek, hangi enerji türlerinin baskın olduğunu belirlemenizi sağlar.
#
# - **2.3 Ülkelerin Enerji Üretim Miktarı ve Üretim Şekli Açısından İnceleme:**
#   Enerji üretim miktarını ve üretim yöntemlerini ülkelere göre karşılaştırmak, ülkeler arası farkları ortaya çıkarır.
#
# - **2.4 Ülkelerin Enerji Üretim Miktarı ve Kamu-Özel Ortaklığı Üretim Açısından İnceleme:**
#   Kamu ve özel sektörün enerji üretimindeki rolünü incelemek, enerji sektöründeki ortaklıkların etkilerini değerlendirmeyi sağlar.
#
# - **2.5 Ülkelerin Enerji Üretim Miktarı ve Bölgesel Anlaşmalı Üretim Açısından İnceleme:**
#   Bölgesel anlaşmaların enerji üretimine etkilerini incelemek, enerji üretimindeki uluslararası iş birliklerini anlamanıza yardımcı olur.
#
# - **2.6 Kurulu Kapasiteye Bakalım:**
#   Enerji üretiminde kullanılan toplam kurulu kapasiteyi incelemek, enerji altyapısının büyüklüğünü gösterir.
#
# - **2.7 Üretim Kapasitesinin Ülkeler Açısından İnceleme:**
#   Farklı ülkelerin enerji üretim kapasitesini karşılaştırmak, enerji üretiminde ülkeler arası farkları ortaya koyar.
#
# - **2.8 Fransa Özelinde Rusya-Ukrayna Savaşı Sonrası Fransa'nın Üretim Kapasitesini Artırma Politikaları:**
#   Savaş sonrası enerji politikalarını incelemek, Fransa'nın enerji güvenliğini nasıl sağladığını gösterir.
#
# - **2.9 Üretim Kapasitesi ve Yıl Odaklı İnceleme:**
#   Yıllara göre üretim kapasitesindeki değişiklikleri analiz etmek, zaman içindeki eğilimleri gösterir.
#
# - **2.10 Yıllara ve Üretim Miktarına Göre İnceleme:**
#   Yıllar ve üretim türlerine göre enerji üretimini incelemek, üretim türlerinin zaman içindeki değişimini gösterir.
#
# - **2.11 Üretim Kapasitesi Bakımından Yıllara ve Üretim Türlerine Göre İnceleme:**
#   Enerji üretim kapasitesindeki yıllık ve türler bazındaki değişimleri incelemek, enerji türlerinin yıllık performansını gösterir.
#
# - **2.12 Enerji Tüketimine Yıllara Göre Bakalım:**
#   Enerji tüketimindeki yıllık değişiklikleri incelemek, tüketim eğilimlerini gösterir.
#
# - **2.13 Enerji Tüketimine Yıllara Göre ve Enerji Üretim Türleri Açısından Bakalım:**
#   Enerji tüketiminin yıllık değişiklikleri ve üretim türleri ile olan ilişkisini incelemek, enerji tüketimi ve üretimi arasındaki ilişkiyi anlamayı sağlar.
#
# - **2.14 Yıllara Göre Yenilenebilir Enerji Oranı:**
#   Yenilenebilir enerji oranındaki yıllık değişiklikleri incelemek, yenilenebilir enerji kaynaklarının zaman içindeki artışını gösterir.
#
# - **2.15 Yıllara Göre Yenilenebilir Enerji Oranını Ülkelere Odaklı İnceleme:**
#   Ülkelere göre yenilenebilir enerji oranlarını yıllık bazda incelemek, ülkeler arasındaki yenilenebilir enerji kullanımını karşılaştırır.
#
# - **2.16 Yenilenebilir Enerji Kaynakları Açısından Ülkeleri 2023 Yılı İçin İnceleme:**
#   2023 yılı için yenilenebilir enerji kaynaklarını ülkeler bazında incelemek, güncel yenilenebilir enerji kullanımını gösterir.
#
# - **2.17 Yenilenebilir Enerji Kaynaklarının Oranı ve Yapılma Proje Anlaşmaları:**
#   Yenilenebilir enerji oranlarını ve ilgili projeleri incelemek, yenilenebilir enerjiye yönelik projelerin etkilerini değerlendirir.
#
# - **2.18 Kişi Başına Düşen Milli Gelir ve Enerji Üretimi Dağılımı:**
#   Kişi başına düşen milli gelir ve enerji üretimi arasındaki ilişkiyi incelemek, ekonomik durum ile enerji üretimi arasındaki bağlantıyı anlamanızı sağlar.
#
# ## 3. Model Kurma:
#
# - **3.1 Doğrusal Regresyon:**
#   Enerji üretimi ve diğer faktörler arasındaki ilişkileri modellemek için doğrusal regresyon kullanılır. Bu, basit ve hızlı bir analiz yöntemidir.
#
# - **3.2 Lojistik Regresyon:**
#   Kategorik değişkenler için tahmin yapmada kullanılır. Özellikle sınıflandırma problemlerinde etkili olabilir.
#
# - **3.3 Destek Vektör Makinesi (SVM):**
#   Karmaşık verilerde yüksek doğruluk sağlamak için kullanılır. Özellikle sınırları belirlemek için etkili bir yöntemdir.
#
# - **3.4 Karar Ağaçları:**
#   Karar ağaçları, verileri ağaç yapısında analiz eder ve sonuçlara ulaşmada yardımcı olur. Görselleştirilmesi kolaydır ve açıklayıcıdır.
#
# - **3.5 Yapay Sinir Ağı ile Model Kurma:**
#   Derin öğrenme yöntemlerini kullanarak daha karmaşık ilişkileri modellemeye çalışır. Daha yüksek doğruluk ve genel performans sağlar.
#
# - **3.6 Model Sonucuna Bakalım:**
#   Modellerin performansını değerlendirmek ve hangi modelin en iyi sonuçları verdiğini analiz etmek.
#
# - **3.7 Model Sonuçlarını Görselleştirelim:**
#   Model sonuçlarını grafikler ve tablolar aracılığıyla görselleştirmek, sonuçların daha anlaşılır hale gelmesini sağlar.
#
# - **3.8 Veri Setinden Veri Seçip Rastgele Tahmin Yaptırma:**
#   Rastgele seçilen verilerle model tahminleri yaparak modelin genel performansını test etmek.
#
# - **3.9 Seçilen Değerleri Görselleştirelim:**
#   Rastgele tahminlerin görselleştirilmesi, tahminlerin ne kadar doğru olduğunu görsel olarak anlamanıza yardımcı olur.
